# %% [markdown]
# # Forms Recogniser Python Example
#
# 6th April 2020
#
# Microsoft Forms Recogniser Python Tutorial
#
#
# https://docs.microsoft.com/en-us/azure/cognitive-services/form-recognizer/quickstarts/python-train-extract

# %% [markdown]
# ## 1. Load the Required Libraries

# %%
# load environment variables
import azure, json, os, requests
import pandas as pd
from dotenv import load_dotenv
import sys
import time
from requests import get, post

# %%
load_dotenv(verbose=True)
# Out:
# True

# %% [markdown]
# ## 2. Train the Model

# %%
########### Python Form Recognizer Labeled Async Train #############

# Endpoint URL
endpoint = r"https://formrecogniserapi.cognitiveservices.azure.com/"
post_url = endpoint + r"/formrecognizer/v2.0-preview/custom/models"
source = r"https://formsstorageamc.blob.core.windows.net/trainingforms?"+os.getenv("SAS_KEY")
prefix = ""
includeSubFolders = False
useLabelFile = False

headers = {
    # Request headers
    'Content-Type': 'application/json',
    'Ocp-Apim-Subscription-Key': os.getenv("SUBKEY"),
}

body = 	{
    "source": source,
    "sourceFilter": {
        "prefix": prefix,
        "includeSubFolders": includeSubFolders
    },
    "useLabelFile": useLabelFile
}

try:
    resp = post(url = post_url, json = body, headers = headers)
    if resp.status_code != 201:
        print("POST model failed (%s):\n%s" % (resp.status_code, json.dumps(resp.json())))
        quit()
    print("POST model succeeded:\n%s" % resp.headers)
    get_url = resp.headers["location"]
except Exception as e:
    print("POST model failed:\n%s" % str(e))
    quit()
# Out:
# POST model succeeded:
# {'Content-Length': '0', 'Location': 'https://formrecogniserapi.cognitiveservices.azure.com/formrecognizer/v2.0-preview/custom/models/7d30db5f-5f1a-4db3-b658-67cfd7fae7e7', 'x-envoy-upstream-service-time': '48', 'apim-request-id': 'c08cc555-c579-43b0-b617-b67013580cf7', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'x-content-type-options': 'nosniff', 'Date': 'Tue, 07 Apr 2020 01:06:15 GMT'}

# %%
# make sure to save the model ID as a variable which we will use in later steps

n_tries = 15
n_try = 0
wait_sec = 5
max_wait_sec = 60
while n_try < n_tries:
    try:
        resp = get(url = get_url, headers = headers)
        resp_json = resp.json()
        if resp.status_code != 200:
            print("GET model failed (%s):\n%s" % (resp.status_code, json.dumps(resp_json)))
            quit()
        model_status = resp_json["modelInfo"]["status"]
        if model_status == "ready":
            print("Training succeeded:\n%s" % json.dumps(resp_json, indent=4, sort_keys=True))
            modelID = resp_json["modelInfo"]["modelId"]
            print(modelID)
            break
        if model_status == "invalid":
            print("Training failed. Model is invalid:\n%s" % json.dumps(resp_json))
            quit()
        # Training still running. Wait and retry.
        time.sleep(wait_sec)
        n_try += 1
        wait_sec = min(2*wait_sec, max_wait_sec)     
    except Exception as e:
        msg = "GET model failed:\n%s" % str(e)
        print(msg)
        quit()
# Out:
# Training succeeded:
# {
#     "modelInfo": {
#         "createdDateTime": "2020-04-07T01:06:15Z",
#         "lastUpdatedDateTime": "2020-04-07T01:06:40Z",
#         "modelId": "7d30db5f-5f1a-4db3-b658-67cfd7fae7e7",
#         "status": "ready"
#     },
#     "trainResult": {
#         "errors": [],
#         "trainingDocuments": [
#             {
#                 "documentName": "SLNI 36 (SLNR 36) - Copy.pdf",
#                 "errors": [],
#                 "pages": 1,
#                 "status": "succeeded"
#             },
#             {
#                 "documentName": "SLNI 36 (SLNR 36).pdf",
#                 "errors": [],
#                 "pages": 1,
#                 "status": "succeeded"
#             },
#             {
#                 "documentName": "SLNR 37.pdf",
#                 "errors": [],
#                 "pages": 1,
#                 "status": "succeeded"
#             },
#             {
#                 "documentName": "VHC7 - Logicapp.pdf",
#                 "errors": [],
#                 "pages": 1,
#                 "status": "succeeded"
#             },
#             {
#                 "documentName": "VHC7 - Logicapp2.pdf",
#                 "errors": [],
#                 "pages": 1,
#                 "status": "succeeded"
#             },
#             {
#                 "documentName": "VHC7.pdf",
#                 "errors": [],
#                 "pages": 1,
#                 "status": "succeeded"
#             },
#             {
#                 "documentName": "VHI6.pdf",
#                 "errors": [],
#                 "pages": 1,
#                 "status": "succeeded"
#             }
#         ]
#     }
# }
# 7d30db5f-5f1a-4db3-b658-67cfd7fae7e7

# %%
x = os.getenv("file_path")
x
# Out:
# 'C:/Users/ancibira/OneDrive - Microsoft/Customers/CSIRO/Plastics Illegal Fishing/FormsRecogniser/First Pages/VHC7.pdf'

# %% [markdown]
# ## 3. Perform Model Inferencing on a Local Dcoument

# %%
# local path of document
source = os.getenv("file_path")

# Endpoint URL
apim_key = os.getenv("SUBKEY")
model_id = modelID
post_url = endpoint + "/formrecognizer/v2.0-preview/custom/models/%s/analyze" % model_id
params = {
    "includeTextDetails": True
}

headers = {
    # Request headers
    'Content-Type': 'application/pdf',
    'Ocp-Apim-Subscription-Key': apim_key,
}
with open(source, "rb") as f:
    data_bytes = f.read()

try:
    resp = post(url = post_url, data = data_bytes, headers = headers, params = params)
    if resp.status_code != 202:
        print("POST analyze failed:\n%s" % json.dumps(resp.json()))
        quit()
    print("POST analyze succeeded:\n%s" % resp.headers)
    get_url = resp.headers["operation-location"]
except Exception as e:
    print("POST analyze failed:\n%s" % str(e))
    quit()
# Out:
# POST analyze succeeded:
# {'Content-Length': '0', 'Operation-Location': 'https://formrecogniserapi.cognitiveservices.azure.com/formrecognizer/v2.0-preview/custom/models/7d30db5f-5f1a-4db3-b658-67cfd7fae7e7/analyzeresults/52c7e81b-bbac-47aa-8439-c4167166a713', 'x-envoy-upstream-service-time': '227', 'apim-request-id': 'ef3d4ff9-251b-461c-b044-6692d8fd73cd', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'x-content-type-options': 'nosniff', 'Date': 'Tue, 07 Apr 2020 01:06:54 GMT'}

# %%
n_tries = 15
n_try = 0
wait_sec = 5
max_wait_sec = 60
while n_try < n_tries:
    try:
        resp = get(url = get_url, headers = {"Ocp-Apim-Subscription-Key": apim_key})
        resp_json = resp.json()
        if resp.status_code != 200:
            print("GET analyze results failed:\n%s" % json.dumps(resp_json))
            quit()
        status = resp_json["status"]
        if status == "succeeded":
            print("Analysis succeeded:\n%s" % json.dumps(resp_json, indent=4, sort_keys=True))
            break
        if status == "failed":
            print("Analysis failed:\n%s" % json.dumps(resp_json))
            quit()
        # Analysis still running. Wait and retry.
        time.sleep(wait_sec)
        n_try += 1
        wait_sec = min(2*wait_sec, max_wait_sec)     
    except Exception as e:
        msg = "GET analyze results failed:\n%s" % str(e)
        print(msg)
        quit()
# Out:
# Analysis succeeded:
# {
#     "analyzeResult": {
#         "documentResults": [],
#         "errors": [],
#         "pageResults": [
#             {
#                 "clusterId": 0,
#                 "keyValuePairs": [
#                     {
#                         "confidence": 0.82,
#                         "key": {
#                             "boundingBox": [
#                                 0.5347,
#                                 3.6319,
#                                 1.7111,
#                                 3.6319,
#                                 1.7111,
#                                 3.7569,
#                                 0.5347,
#                                 3.7569
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/24/words/0"
#                             ],
#                             "text": "Location/Municipality"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 1.9611,
#                                 3.5861,
#                                 3.5444,
#                                 3.5861,
#                                 3.5444,
#                                 3.8083,
#                                 1.9611,
#                                 3.8083
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/25/words/0",
#                                 "#/readResults/0/lines/25/words/1",
#                                 "#/readResults/0/lines/25/words/2"
#                             ],
#                             "text": "Trans ludo Never"
#                         }
#                     },
#                     {
#                         "confidence": 0.7,
#                         "key": {
#                             "boundingBox": [
#                                 0.5306,
#                                 3.8861,
#                                 1.0069,
#                                 3.8861,
#                                 1.0069,
#                                 4.0069,
#                                 0.5306,
#                                 4.0069
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/27/words/0"
#                             ],
#                             "text": "Country:"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 2.0972,
#                                 3.8444,
#                                 2.8444,
#                                 3.8444,
#                                 2.8444,
#                                 4.0486,
#                                 2.0972,
#                                 4.0486
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/28/words/0",
#                                 "#/readResults/0/lines/28/words/1"
#                             ],
#                             "text": "Viet Nam"
#                         }
#                     },
#                     {
#                         "confidence": 0.82,
#                         "key": {
#                             "boundingBox": [
#                                 0.5278,
#                                 4.1389,
#                                 1.1972,
#                                 4.1389,
#                                 1.1972,
#                                 4.2472,
#                                 0.5278,
#                                 4.2472
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/30/words/0",
#                                 "#/readResults/0/lines/30/words/1"
#                             ],
#                             "text": "Survey date:"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 2.2778,
#                                 4.0694,
#                                 3.1361,
#                                 4.0694,
#                                 3.1361,
#                                 4.2944,
#                                 2.2778,
#                                 4.2944
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/32/words/0",
#                                 "#/readResults/0/lines/32/words/1"
#                             ],
#                             "text": "715/ 2018"
#                         }
#                     },
#                     {
#                         "confidence": 0.5,
#                         "key": {
#                             "boundingBox": [
#                                 5.0417,
#                                 4.1181,
#                                 6.9472,
#                                 4.1181,
#                                 6.9472,
#                                 4.2292,
#                                 5.0417,
#                                 4.2292
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/31/words/0",
#                                 "#/readResults/0/lines/31/words/1",
#                                 "#/readResults/0/lines/31/words/2",
#                                 "#/readResults/0/lines/31/words/3"
#                             ],
#                             "text": "Date survey undertaken (dd/mm/yyyy)"
#                         },
#                         "value": {
#                             "boundingBox": null,
#                             "elements": null,
#                             "text": ""
#                         }
#                     },
#                     {
#                         "confidence": 0.7,
#                         "key": {
#                             "boundingBox": [
#                                 5.0486,
#                                 4.3542,
#                                 6.0111,
#                                 4.3542,
#                                 6.0111,
#                                 4.4694,
#                                 5.0486,
#                                 4.4694
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/33/words/0",
#                                 "#/readResults/0/lines/33/words/1",
#                                 "#/readResults/0/lines/33/words/2",
#                                 "#/readResults/0/lines/33/words/3"
#                             ],
#                             "text": "Unique name of site"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 5.0417,
#                                 4.5903,
#                                 7.6694,
#                                 4.5903,
#                                 7.6694,
#                                 5.4514,
#                                 5.0417,
#                                 5.4514
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/38/words/0",
#                                 "#/readResults/0/lines/38/words/1",
#                                 "#/readResults/0/lines/38/words/2",
#                                 "#/readResults/0/lines/38/words/3",
#                                 "#/readResults/0/lines/38/words/4",
#                                 "#/readResults/0/lines/38/words/5",
#                                 "#/readResults/0/lines/38/words/6",
#                                 "#/readResults/0/lines/38/words/7",
#                                 "#/readResults/0/lines/38/words/8",
#                                 "#/readResults/0/lines/38/words/9",
#                                 "#/readResults/0/lines/46/words/0",
#                                 "#/readResults/0/lines/46/words/1",
#                                 "#/readResults/0/lines/46/words/2",
#                                 "#/readResults/0/lines/46/words/3",
#                                 "#/readResults/0/lines/46/words/4",
#                                 "#/readResults/0/lines/46/words/5",
#                                 "#/readResults/0/lines/46/words/6",
#                                 "#/readResults/0/lines/46/words/7",
#                                 "#/readResults/0/lines/47/words/0",
#                                 "#/readResults/0/lines/47/words/1",
#                                 "#/readResults/0/lines/47/words/2",
#                                 "#/readResults/0/lines/47/words/3",
#                                 "#/readResults/0/lines/47/words/4",
#                                 "#/readResults/0/lines/47/words/5",
#                                 "#/readResults/0/lines/47/words/6"
#                             ],
#                             "text": "The name of photographer and photo #s from the site by instantaneous count. Visible distance is length of shore with a clear and unobstructed view."
#                         }
#                     },
#                     {
#                         "confidence": 0.7,
#                         "key": {
#                             "boundingBox": [
#                                 0.5306,
#                                 4.3861,
#                                 1.1389,
#                                 4.3861,
#                                 1.1389,
#                                 4.5028,
#                                 0.5306,
#                                 4.5028
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/34/words/0",
#                                 "#/readResults/0/lines/34/words/1"
#                             ],
#                             "text": "Site name:"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 2.1639,
#                                 4.3681,
#                                 2.7014,
#                                 4.3681,
#                                 2.7014,
#                                 4.5583,
#                                 2.1639,
#                                 4.5583
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/35/words/0"
#                             ],
#                             "text": "VICE"
#                         }
#                     },
#                     {
#                         "confidence": 0.7,
#                         "key": {
#                             "boundingBox": [
#                                 0.5306,
#                                 4.6083,
#                                 1.125,
#                                 4.6083,
#                                 1.125,
#                                 4.7389,
#                                 0.5306,
#                                 4.7389
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/36/words/0",
#                                 "#/readResults/0/lines/36/words/1"
#                             ],
#                             "text": "Photo info:"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 2.0764,
#                                 4.5764,
#                                 3.1806,
#                                 4.5764,
#                                 3.1806,
#                                 4.7847,
#                                 2.0764,
#                                 4.7847
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/37/words/0",
#                                 "#/readResults/0/lines/37/words/1",
#                                 "#/readResults/0/lines/37/words/2"
#                             ],
#                             "text": "VICE - site"
#                         }
#                     },
#                     {
#                         "confidence": 0.82,
#                         "key": {
#                             "boundingBox": [
#                                 1.8778,
#                                 4.9,
#                                 2.9278,
#                                 4.9,
#                                 2.9278,
#                                 5.0806,
#                                 1.8778,
#                                 5.0806
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/39/words/0",
#                                 "#/readResults/0/lines/39/words/1",
#                                 "#/readResults/0/lines/39/words/2",
#                                 "#/readResults/0/lines/39/words/3"
#                             ],
#                             "text": "Time of day (00:00):"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 2.9556,
#                                 4.9,
#                                 3.6667,
#                                 4.9,
#                                 3.6667,
#                                 5.0806,
#                                 2.9556,
#                                 5.0806
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/40/words/0"
#                             ],
#                             "text": "!!.Q..:...5.0)."
#                         }
#                     },
#                     {
#                         "confidence": 0.7,
#                         "key": {
#                             "boundingBox": [
#                                 0.5278,
#                                 5.2056,
#                                 1.6389,
#                                 5.2056,
#                                 1.6389,
#                                 5.3361,
#                                 0.5278,
#                                 5.3361
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/42/words/0",
#                                 "#/readResults/0/lines/42/words/1",
#                                 "#/readResults/0/lines/42/words/2"
#                             ],
#                             "text": "Number of humans:"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 3.2153,
#                                 5.3722,
#                                 3.3083,
#                                 5.3722,
#                                 3.3083,
#                                 5.4972,
#                                 3.2153,
#                                 5.4972
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/48/words/0"
#                             ],
#                             "text": "4"
#                         }
#                     },
#                     {
#                         "confidence": 0.7,
#                         "key": {
#                             "boundingBox": [
#                                 1.8778,
#                                 5.1556,
#                                 3.0167,
#                                 5.1556,
#                                 3.0167,
#                                 5.3361,
#                                 1.8778,
#                                 5.3361
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/43/words/0",
#                                 "#/readResults/0/lines/43/words/1",
#                                 "#/readResults/0/lines/43/words/2"
#                             ],
#                             "text": "Visible distance (m):"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 3.0903,
#                                 5.1556,
#                                 3.1833,
#                                 5.1556,
#                                 3.1833,
#                                 5.3361,
#                                 3.0903,
#                                 5.3361
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/44/words/0"
#                             ],
#                             "text": "4"
#                         }
#                     },
#                     {
#                         "confidence": 0.5,
#                         "key": {
#                             "boundingBox": [
#                                 1.8722,
#                                 5.4417,
#                                 2.6361,
#                                 5.4417,
#                                 2.6361,
#                                 5.5806,
#                                 1.8722,
#                                 5.5806
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/49/words/0",
#                                 "#/readResults/0/lines/49/words/1",
#                                 "#/readResults/0/lines/49/words/2"
#                             ],
#                             "text": "No. of people:"
#                         },
#                         "value": {
#                             "boundingBox": null,
#                             "elements": null,
#                             "text": ""
#                         }
#                     },
#                     {
#                         "confidence": 0.5,
#                         "key": {
#                             "boundingBox": [
#                                 2.1111,
#                                 5.6972,
#                                 2.4,
#                                 5.6972,
#                                 2.4,
#                                 5.8361,
#                                 2.1111,
#                                 5.8361
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/51/words/0"
#                             ],
#                             "text": "Clear"
#                         },
#                         "value": {
#                             "boundingBox": null,
#                             "elements": null,
#                             "text": ""
#                         }
#                     },
#                     {
#                         "confidence": 1.0,
#                         "key": {
#                             "boundingBox": [
#                                 2.6833,
#                                 5.7014,
#                                 3.2639,
#                                 5.7014,
#                                 3.2639,
#                                 5.8167,
#                                 2.6833,
#                                 5.8167
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/52/words/0"
#                             ],
#                             "text": "Rain/Storm"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 3.3083,
#                                 6.125,
#                                 3.3542,
#                                 6.125,
#                                 3.3542,
#                                 6.2667,
#                                 3.3083,
#                                 6.2667
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/60/words/0"
#                             ],
#                             "text": "2"
#                         }
#                     },
#                     {
#                         "confidence": 0.7,
#                         "key": {
#                             "boundingBox": [
#                                 3.625,
#                                 5.7083,
#                                 4.0444,
#                                 5.7083,
#                                 4.0444,
#                                 5.8167,
#                                 3.625,
#                                 5.8167
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/53/words/0"
#                             ],
#                             "text": "Overcast"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 4.2944,
#                                 5.9056,
#                                 4.3861,
#                                 5.9056,
#                                 4.3861,
#                                 6.0389,
#                                 4.2944,
#                                 6.0389
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/56/words/0"
#                             ],
#                             "text": "0:"
#                         }
#                     },
#                     {
#                         "confidence": 0.7,
#                         "key": {
#                             "boundingBox": [
#                                 4.4028,
#                                 5.6972,
#                                 4.7333,
#                                 5.6972,
#                                 4.7333,
#                                 5.8167,
#                                 4.4028,
#                                 5.8167
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/54/words/0"
#                             ],
#                             "text": "Drizzle"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 4.4139,
#                                 5.9056,
#                                 5.2806,
#                                 5.9056,
#                                 5.2806,
#                                 6.0389,
#                                 4.4139,
#                                 6.0389
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/57/words/0",
#                                 "#/readResults/0/lines/57/words/1",
#                                 "#/readResults/0/lines/57/words/2"
#                             ],
#                             "text": "calm (flat ocean)"
#                         }
#                     },
#                     {
#                         "confidence": 0.7,
#                         "key": {
#                             "boundingBox": [
#                                 4.2944,
#                                 6.0417,
#                                 4.3722,
#                                 6.0417,
#                                 4.3722,
#                                 6.1875,
#                                 4.2944,
#                                 6.1875
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/58/words/0"
#                             ],
#                             "text": "1:"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 4.4,
#                                 6.0417,
#                                 6.5167,
#                                 6.0417,
#                                 6.5167,
#                                 6.1875,
#                                 4.4,
#                                 6.1875
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/59/words/0",
#                                 "#/readResults/0/lines/59/words/1",
#                                 "#/readResults/0/lines/59/words/2",
#                                 "#/readResults/0/lines/59/words/3",
#                                 "#/readResults/0/lines/59/words/4",
#                                 "#/readResults/0/lines/59/words/5"
#                             ],
#                             "text": "light breeze (wavelets, <10km/h, < knots)"
#                         }
#                     },
#                     {
#                         "confidence": 0.7,
#                         "key": {
#                             "boundingBox": [
#                                 4.2889,
#                                 6.1917,
#                                 4.3778,
#                                 6.1917,
#                                 4.3778,
#                                 6.3333,
#                                 4.2889,
#                                 6.3333
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/61/words/0"
#                             ],
#                             "text": "2:"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 4.4056,
#                                 6.1917,
#                                 7.7847,
#                                 6.1917,
#                                 7.7847,
#                                 6.3333,
#                                 4.4056,
#                                 6.3333
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/62/words/0",
#                                 "#/readResults/0/lines/62/words/1",
#                                 "#/readResults/0/lines/62/words/2",
#                                 "#/readResults/0/lines/62/words/3",
#                                 "#/readResults/0/lines/62/words/4",
#                                 "#/readResults/0/lines/62/words/5",
#                                 "#/readResults/0/lines/62/words/6",
#                                 "#/readResults/0/lines/62/words/7",
#                                 "#/readResults/0/lines/62/words/8"
#                             ],
#                             "text": "moderate breeze (small waves braking crests, 10-25km/h, 6-20 knots)"
#                         }
#                     },
#                     {
#                         "confidence": 1.0,
#                         "key": {
#                             "boundingBox": [
#                                 0.5306,
#                                 6.2889,
#                                 1.225,
#                                 6.2889,
#                                 1.225,
#                                 6.4375,
#                                 0.5306,
#                                 6.4375
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/63/words/0",
#                                 "#/readResults/0/lines/63/words/1"
#                             ],
#                             "text": "Wind speed:"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 2.5903,
#                                 6.4375,
#                                 2.6597,
#                                 6.4375,
#                                 2.6597,
#                                 6.5306,
#                                 2.5903,
#                                 6.5306
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/66/words/0"
#                             ],
#                             "text": "3"
#                         }
#                     },
#                     {
#                         "confidence": 0.95,
#                         "key": {
#                             "boundingBox": [
#                                 0.5306,
#                                 6.9056,
#                                 1.375,
#                                 6.9056,
#                                 1.375,
#                                 7.0528,
#                                 0.5306,
#                                 7.0528
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/71/words/0",
#                                 "#/readResults/0/lines/71/words/1"
#                             ],
#                             "text": "Wind direction:"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 2.3722,
#                                 6.9833,
#                                 2.5486,
#                                 6.9833,
#                                 2.5486,
#                                 7.1222,
#                                 2.3722,
#                                 7.1222
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/73/words/0"
#                             ],
#                             "text": "NE"
#                         }
#                     },
#                     {
#                         "confidence": 0.7,
#                         "key": {
#                             "boundingBox": [
#                                 0.5417,
#                                 7.0764,
#                                 1.0903,
#                                 7.0764,
#                                 1.0903,
#                                 7.2194,
#                                 0.5417,
#                                 7.2194
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/80/words/0"
#                             ],
#                             "text": "(compass)"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 2.3333,
#                                 7.4375,
#                                 2.7778,
#                                 7.4375,
#                                 2.7778,
#                                 7.5833,
#                                 2.3333,
#                                 7.5833
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/84/words/0"
#                             ],
#                             "text": "onshore"
#                         }
#                     },
#                     {
#                         "confidence": 0.82,
#                         "key": {
#                             "boundingBox": [
#                                 5.0625,
#                                 7.2986,
#                                 5.4931,
#                                 7.2986,
#                                 5.4931,
#                                 7.4139,
#                                 5.0625,
#                                 7.4139
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/82/words/0"
#                             ],
#                             "text": "Onshore:"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 5.5167,
#                                 7.2986,
#                                 6.9028,
#                                 7.2986,
#                                 6.9028,
#                                 7.4139,
#                                 5.5167,
#                                 7.4139
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/83/words/0",
#                                 "#/readResults/0/lines/83/words/1",
#                                 "#/readResults/0/lines/83/words/2",
#                                 "#/readResults/0/lines/83/words/3"
#                             ],
#                             "text": "wind blowing towards shore"
#                         }
#                     },
#                     {
#                         "confidence": 0.7,
#                         "key": {
#                             "boundingBox": [
#                                 5.0556,
#                                 7.4375,
#                                 5.5069,
#                                 7.4375,
#                                 5.5069,
#                                 7.5625,
#                                 5.0556,
#                                 7.5625
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/87/words/0"
#                             ],
#                             "text": "Offshore:"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 5.5347,
#                                 7.4375,
#                                 6.8125,
#                                 7.4375,
#                                 6.8125,
#                                 7.5625,
#                                 5.5347,
#                                 7.5625
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/88/words/0",
#                                 "#/readResults/0/lines/88/words/1",
#                                 "#/readResults/0/lines/88/words/2",
#                                 "#/readResults/0/lines/88/words/3"
#                             ],
#                             "text": "wind blowing towards sea"
#                         }
#                     },
#                     {
#                         "confidence": 0.82,
#                         "key": {
#                             "boundingBox": [
#                                 5.0625,
#                                 7.5806,
#                                 5.5583,
#                                 7.5806,
#                                 5.5583,
#                                 7.7056,
#                                 5.0625,
#                                 7.7056
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/90/words/0"
#                             ],
#                             "text": "Sideshore:"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 5.5833,
#                                 7.5806,
#                                 7.0722,
#                                 7.5806,
#                                 7.0722,
#                                 7.7056,
#                                 5.5833,
#                                 7.7056
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/91/words/0",
#                                 "#/readResults/0/lines/91/words/1",
#                                 "#/readResults/0/lines/91/words/2",
#                                 "#/readResults/0/lines/91/words/3",
#                                 "#/readResults/0/lines/91/words/4"
#                             ],
#                             "text": "wind blowing parallel to shore"
#                         }
#                     },
#                     {
#                         "confidence": 0.7,
#                         "key": {
#                             "boundingBox": [
#                                 5.0694,
#                                 7.725,
#                                 5.7194,
#                                 7.725,
#                                 5.7194,
#                                 7.8472,
#                                 5.0694,
#                                 7.8472
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/93/words/0"
#                             ],
#                             "text": "Side-onshore:"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 5.7431,
#                                 7.725,
#                                 7.8333,
#                                 7.725,
#                                 7.8333,
#                                 7.8472,
#                                 5.7431,
#                                 7.8472
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/94/words/0",
#                                 "#/readResults/0/lines/94/words/1",
#                                 "#/readResults/0/lines/94/words/2",
#                                 "#/readResults/0/lines/94/words/3",
#                                 "#/readResults/0/lines/94/words/4",
#                                 "#/readResults/0/lines/94/words/5"
#                             ],
#                             "text": "wind blowing sideways and towards share"
#                         }
#                     },
#                     {
#                         "confidence": 0.82,
#                         "key": {
#                             "boundingBox": [
#                                 2.8306,
#                                 7.7708,
#                                 3.2292,
#                                 7.7708,
#                                 3.2292,
#                                 7.8861,
#                                 2.8306,
#                                 7.8861
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/95/words/0"
#                             ],
#                             "text": "side-on"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 3.6222,
#                                 7.7611,
#                                 4.0306,
#                                 7.7611,
#                                 4.0306,
#                                 7.8861,
#                                 3.6222,
#                                 7.8861
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/96/words/0"
#                             ],
#                             "text": "side-off"
#                         }
#                     },
#                     {
#                         "confidence": 0.7,
#                         "key": {
#                             "boundingBox": [
#                                 5.0583,
#                                 7.8639,
#                                 5.7333,
#                                 7.8639,
#                                 5.7333,
#                                 7.9931,
#                                 5.0583,
#                                 7.9931
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/97/words/0"
#                             ],
#                             "text": "Side-offshore:"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 5.7569,
#                                 7.8639,
#                                 7.7222,
#                                 7.8639,
#                                 7.7222,
#                                 7.9931,
#                                 5.7569,
#                                 7.9931
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/98/words/0",
#                                 "#/readResults/0/lines/98/words/1",
#                                 "#/readResults/0/lines/98/words/2",
#                                 "#/readResults/0/lines/98/words/3",
#                                 "#/readResults/0/lines/98/words/4",
#                                 "#/readResults/0/lines/98/words/5"
#                             ],
#                             "text": "wind blowing sideways and towards sea"
#                         }
#                     },
#                     {
#                         "confidence": 0.7,
#                         "key": {
#                             "boundingBox": [
#                                 0.5444,
#                                 8.1528,
#                                 1.7153,
#                                 8.1528,
#                                 1.7153,
#                                 8.275,
#                                 0.5444,
#                                 8.275
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/99/words/0",
#                                 "#/readResults/0/lines/99/words/1",
#                                 "#/readResults/0/lines/99/words/2",
#                                 "#/readResults/0/lines/99/words/3",
#                                 "#/readResults/0/lines/99/words/4"
#                             ],
#                             "text": "Date of last clean up:"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 0.5486,
#                                 8.4194,
#                                 1.2847,
#                                 8.4194,
#                                 1.2847,
#                                 8.5278,
#                                 0.5486,
#                                 8.5278
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/102/words/0",
#                                 "#/readResults/0/lines/102/words/1",
#                                 "#/readResults/0/lines/102/words/2"
#                             ],
#                             "text": "Access to site"
#                         }
#                     },
#                     {
#                         "confidence": 0.7,
#                         "key": {
#                             "boundingBox": [
#                                 2.3194,
#                                 8.4194,
#                                 2.6639,
#                                 8.4194,
#                                 2.6639,
#                                 8.5444,
#                                 2.3194,
#                                 8.5444
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/103/words/0"
#                             ],
#                             "text": "Paved"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 3.2806,
#                                 8.375,
#                                 3.7569,
#                                 8.375,
#                                 3.7569,
#                                 8.5069,
#                                 3.2806,
#                                 8.5069
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/104/words/0"
#                             ],
#                             "text": "Inpaved"
#                         }
#                     },
#                     {
#                         "confidence": 0.5,
#                         "key": {
#                             "boundingBox": [
#                                 4.7847,
#                                 8.3778,
#                                 5.6111,
#                                 8.3778,
#                                 5.6111,
#                                 8.5069,
#                                 4.7847,
#                                 8.5069
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/106/words/0",
#                                 "#/readResults/0/lines/106/words/1"
#                             ],
#                             "text": "Other (specify):"
#                         },
#                         "value": {
#                             "boundingBox": null,
#                             "elements": null,
#                             "text": ""
#                         }
#                     },
#                     {
#                         "confidence": 1.0,
#                         "key": {
#                             "boundingBox": [
#                                 0.5556,
#                                 8.6639,
#                                 2.4167,
#                                 8.6639,
#                                 2.4167,
#                                 8.7667,
#                                 0.5556,
#                                 8.7667
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/107/words/0",
#                                 "#/readResults/0/lines/107/words/1",
#                                 "#/readResults/0/lines/107/words/2",
#                                 "#/readResults/0/lines/107/words/3",
#                                 "#/readResults/0/lines/107/words/4",
#                                 "#/readResults/0/lines/107/words/5"
#                             ],
#                             "text": "Trash cans or rubbish bins present?"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 3.2389,
#                                 8.6111,
#                                 3.4792,
#                                 8.6111,
#                                 3.4792,
#                                 8.7667,
#                                 3.2389,
#                                 8.7667
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/108/words/0"
#                             ],
#                             "text": "Yes"
#                         }
#                     },
#                     {
#                         "confidence": 0.5,
#                         "key": {
#                             "boundingBox": [
#                                 0.5625,
#                                 9.5722,
#                                 1.6083,
#                                 9.5722,
#                                 1.6083,
#                                 9.6972,
#                                 0.5625,
#                                 9.6972
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/120/words/0",
#                                 "#/readResults/0/lines/120/words/1",
#                                 "#/readResults/0/lines/120/words/2",
#                                 "#/readResults/0/lines/120/words/3"
#                             ],
#                             "text": "(circle one or more)"
#                         },
#                         "value": {
#                             "boundingBox": null,
#                             "elements": null,
#                             "text": ""
#                         }
#                     },
#                     {
#                         "confidence": 0.5,
#                         "key": {
#                             "boundingBox": [
#                                 3.0347,
# ...
#                             {
#                                 "boundingBox": [
#                                     6.5903,
#                                     9.8125,
#                                     6.8819,
#                                     9.8125,
#                                     6.8819,
#                                     9.9514,
#                                     6.5903,
#                                     9.9514
#                                 ],
#                                 "text": "trash"
#                             },
#                             {
#                                 "boundingBox": [
#                                     6.9056,
#                                     9.8125,
#                                     7.025,
#                                     9.8125,
#                                     7.025,
#                                     9.9514,
#                                     6.9056,
#                                     9.9514
#                                 ],
#                                 "text": "or"
#                             },
#                             {
#                                 "boundingBox": [
#                                     7.0528,
#                                     9.8125,
#                                     7.4861,
#                                     9.8125,
#                                     7.4861,
#                                     9.9514,
#                                     7.0528,
#                                     9.9514
#                                 ],
#                                 "text": "rubbish"
#                             }
#                         ]
#                     },
#                     {
#                         "boundingBox": [
#                             0.5583,
#                             9.8917,
#                             2.4833,
#                             9.8917,
#                             2.4833,
#                             10.0167,
#                             0.5583,
#                             10.0167
#                         ],
#                         "text": "Evidence of recent activities at site:",
#                         "words": [
#                             {
#                                 "boundingBox": [
#                                     0.5583,
#                                     9.8917,
#                                     1.0417,
#                                     9.8917,
#                                     1.0417,
#                                     10.0167,
#                                     0.5583,
#                                     10.0167
#                                 ],
#                                 "text": "Evidence"
#                             },
#                             {
#                                 "boundingBox": [
#                                     1.0667,
#                                     9.8917,
#                                     1.1806,
#                                     9.8917,
#                                     1.1806,
#                                     10.0167,
#                                     1.0667,
#                                     10.0167
#                                 ],
#                                 "text": "of"
#                             },
#                             {
#                                 "boundingBox": [
#                                     1.2056,
#                                     9.8917,
#                                     1.5694,
#                                     9.8917,
#                                     1.5694,
#                                     10.0167,
#                                     1.2056,
#                                     10.0167
#                                 ],
#                                 "text": "recent"
#                             },
#                             {
#                                 "boundingBox": [
#                                     1.5944,
#                                     9.8917,
#                                     2.0694,
#                                     9.8917,
#                                     2.0694,
#                                     10.0167,
#                                     1.5944,
#                                     10.0167
#                                 ],
#                                 "text": "activities"
#                             },
#                             {
#                                 "boundingBox": [
#                                     2.0972,
#                                     9.8917,
#                                     2.2083,
#                                     9.8917,
#                                     2.2083,
#                                     10.0167,
#                                     2.0972,
#                                     10.0167
#                                 ],
#                                 "text": "at"
#                             },
#                             {
#                                 "boundingBox": [
#                                     2.2333,
#                                     9.8917,
#                                     2.4833,
#                                     9.8917,
#                                     2.4833,
#                                     10.0167,
#                                     2.2333,
#                                     10.0167
#                                 ],
#                                 "text": "site:"
#                             }
#                         ]
#                     },
#                     {
#                         "boundingBox": [
#                             0.5486,
#                             10.0625,
#                             1.5903,
#                             10.0625,
#                             1.5903,
#                             10.1778,
#                             0.5486,
#                             10.1778
#                         ],
#                         "text": "(circle one or more)",
#                         "words": [
#                             {
#                                 "boundingBox": [
#                                     0.5486,
#                                     10.0625,
#                                     0.8917,
#                                     10.0625,
#                                     0.8917,
#                                     10.1778,
#                                     0.5486,
#                                     10.1778
#                                 ],
#                                 "text": "(circle"
#                             },
#                             {
#                                 "boundingBox": [
#                                     0.9167,
#                                     10.0625,
#                                     1.1278,
#                                     10.0625,
#                                     1.1278,
#                                     10.1778,
#                                     0.9167,
#                                     10.1778
#                                 ],
#                                 "text": "one"
#                             },
#                             {
#                                 "boundingBox": [
#                                     1.1528,
#                                     10.0625,
#                                     1.2639,
#                                     10.0625,
#                                     1.2639,
#                                     10.1778,
#                                     1.1528,
#                                     10.1778
#                                 ],
#                                 "text": "or"
#                             },
#                             {
#                                 "boundingBox": [
#                                     1.2889,
#                                     10.0625,
#                                     1.5903,
#                                     10.0625,
#                                     1.5903,
#                                     10.1778,
#                                     1.2889,
#                                     10.1778
#                                 ],
#                                 "text": "more)"
#                             }
#                         ]
#                     },
#                     {
#                         "boundingBox": [
#                             3.0347,
#                             10.0528,
#                             3.7917,
#                             10.0528,
#                             3.7917,
#                             10.1778,
#                             3.0347,
#                             10.1778
#                         ],
#                         "text": "Storm or flood",
#                         "words": [
#                             {
#                                 "boundingBox": [
#                                     3.0347,
#                                     10.0528,
#                                     3.3403,
#                                     10.0528,
#                                     3.3403,
#                                     10.1778,
#                                     3.0347,
#                                     10.1778
#                                 ],
#                                 "text": "Storm"
#                             },
#                             {
#                                 "boundingBox": [
#                                     3.4056,
#                                     10.0528,
#                                     3.5208,
#                                     10.0528,
#                                     3.5208,
#                                     10.1778,
#                                     3.4056,
#                                     10.1778
#                                 ],
#                                 "text": "or"
#                             },
#                             {
#                                 "boundingBox": [
#                                     3.5444,
#                                     10.0528,
#                                     3.7917,
#                                     10.0528,
#                                     3.7917,
#                                     10.1778,
#                                     3.5444,
#                                     10.1778
#                                 ],
#                                 "text": "flood"
#                             }
#                         ]
#                     },
#                     {
#                         "boundingBox": [
#                             4.1833,
#                             10.0417,
#                             4.7889,
#                             10.0417,
#                             4.7889,
#                             10.1667,
#                             4.1833,
#                             10.1667
#                         ],
#                         "text": "High winds",
#                         "words": [
#                             {
#                                 "boundingBox": [
#                                     4.1833,
#                                     10.0417,
#                                     4.4375,
#                                     10.0417,
#                                     4.4375,
#                                     10.1667,
#                                     4.1833,
#                                     10.1667
#                                 ],
#                                 "text": "High"
#                             },
#                             {
#                                 "boundingBox": [
#                                     4.4611,
#                                     10.0417,
#                                     4.7889,
#                                     10.0417,
#                                     4.7889,
#                                     10.1667,
#                                     4.4611,
#                                     10.1667
#                                 ],
#                                 "text": "winds"
#                             }
#                         ]
#                     },
#                     {
#                         "boundingBox": [
#                             5.2111,
#                             10.0306,
#                             5.9028,
#                             10.0306,
#                             5.9028,
#                             10.1556,
#                             5.2111,
#                             10.1556
#                         ],
#                         "text": "Public event",
#                         "words": [
#                             {
#                                 "boundingBox": [
#                                     5.2111,
#                                     10.0306,
#                                     5.5417,
#                                     10.0306,
#                                     5.5417,
#                                     10.1556,
#                                     5.2111,
#                                     10.1556
#                                 ],
#                                 "text": "Public"
#                             },
#                             {
#                                 "boundingBox": [
#                                     5.5667,
#                                     10.0306,
#                                     5.9028,
#                                     10.0306,
#                                     5.9028,
#                                     10.1556,
#                                     5.5667,
#                                     10.1556
#                                 ],
#                                 "text": "event"
#                             }
#                         ]
#                     },
#                     {
#                         "boundingBox": [
#                             6.5306,
#                             10.0278,
#                             6.9792,
#                             10.0278,
#                             6.9792,
#                             10.1278,
#                             6.5306,
#                             10.1278
#                         ],
#                         "text": "Mowing",
#                         "words": [
#                             {
#                                 "boundingBox": [
#                                     6.5306,
#                                     10.0278,
#                                     6.9792,
#                                     10.0278,
#                                     6.9792,
#                                     10.1278,
#                                     6.5306,
#                                     10.1278
#                                 ],
#                                 "text": "Mowing"
#                             }
#                         ]
#                     },
#                     {
#                         "boundingBox": [
#                             0.5556,
#                             10.3681,
#                             1.2014,
#                             10.3681,
#                             1.2014,
#                             10.4972,
#                             0.5556,
#                             10.4972
#                         ],
#                         "text": "Comments:",
#                         "words": [
#                             {
#                                 "boundingBox": [
#                                     0.5556,
#                                     10.3681,
#                                     1.2014,
#                                     10.3681,
#                                     1.2014,
#                                     10.4972,
#                                     0.5556,
#                                     10.4972
#                                 ],
#                                 "text": "Comments:"
#                             }
#                         ]
#                     }
#                 ],
#                 "page": 1,
#                 "unit": "inch",
#                 "width": 8.28
#             }
#         ],
#         "version": "2.0.0"
#     },
#     "createdDateTime": "2020-04-07T01:06:55Z",
#     "lastUpdatedDateTime": "2020-04-07T01:07:06Z",
#     "status": "succeeded"
# }
